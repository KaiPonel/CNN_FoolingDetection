# %%
import tensorflow as tf
import os
# Out:
# 2023-06-21 17:24:02.240959: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-21 17:24:08.984394: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.3/lib64:/scratch/ponel/python/lib:/usr/local/cuda-11.3/tensorRT-8.0/lib64:/usr/local/cuda-11.3/cudnn-8.2/lib64:/usr/local/cuda-11.3/nccl-2.9/lib64
# 2023-06-21 17:24:08.984717: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.3/lib64:/scratch/ponel/python/lib:/usr/local/cuda-11.3/tensorRT-8.0/lib64:/usr/local/cuda-11.3/cudnn-8.2/lib64:/usr/local/cuda-11.3/nccl-2.9/lib64
# 2023-06-21 17:24:08.984747: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from lib.ModelProvider import get_model
from lib.DataProvider import load_MNIST, trim_lists
from lib.FeatureProvider import save_grids, load_model_weights
from lib.ExplanationProvider import run_explainers
from lib.AttackProvider import run_random_model_param_test_cascading

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
model_mnist_cifar = get_model(model_type="cnn", dataset="mnist")
model_mnist_cifar = load_model_weights(model=model_mnist_cifar, model_name="cnn", dataset="mnist")
_, _, xTe, yTe = load_MNIST()
xTe, yTe = trim_lists(xTe, yTe, 300) # Only take 20 elements for now

# %%
grids = run_explainers(xTe, yTe, model_mnist_cifar, len(xTe))
save_grids(grids_list=grids, dataset="mnist", model="cnn", attack="correct", override=True)
# Out:
# 300
# image: 0
# 1/1 [==============================] - 0s 288ms/step
# image: 1
# 1/1 [==============================] - 0s 23ms/step
# image: 2
# 1/1 [==============================] - 0s 23ms/step
# image: 3
# /scratch/ponel/python/lib/python3.8/site-packages/tf_explain/utils/display.py:112: RuntimeWarning: invalid value encountered in divide
#   heatmap = (heatmap - np.min(heatmap)) / (heatmap.max() - heatmap.min())
# 1/1 [==============================] - 0s 24ms/step
# image: 4
# WARNING:tensorflow:5 out of the last 5 calls to <function IntegratedGradients.get_integrated_gradients at 0x7fd548123c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function GradientsInputs.compute_gradients at 0x7fd5481233a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function VanillaGradients.compute_gradients at 0x7fd548123820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 32ms/step
# image: 5
# WARNING:tensorflow:6 out of the last 6 calls to <function GradientsInputs.compute_gradients at 0x7fd5481233a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function VanillaGradients.compute_gradients at 0x7fd548123820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 23ms/step
# image: 6
# 1/1 [==============================] - 0s 24ms/step
# image: 7
# WARNING:tensorflow:6 out of the last 8 calls to <function IntegratedGradients.get_integrated_gradients at 0x7fd548123c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 23ms/step
# image: 8
# 1/1 [==============================] - 0s 23ms/step
# image: 9
# 1/1 [==============================] - 0s 23ms/step
# image: 10
# 1/1 [==============================] - 0s 24ms/step
# image: 11
# 1/1 [==============================] - 0s 24ms/step
# image: 12
# 1/1 [==============================] - 0s 25ms/step
# image: 13
# 1/1 [==============================] - 0s 24ms/step
# image: 14
# 1/1 [==============================] - 0s 24ms/step
# image: 15
# 1/1 [==============================] - 0s 24ms/step
# image: 16
# 1/1 [==============================] - 0s 25ms/step
# image: 17
# 1/1 [==============================] - 0s 24ms/step
# image: 18
# 1/1 [==============================] - 0s 24ms/step
# image: 19
# 1/1 [==============================] - 0s 24ms/step
# image: 20
# 1/1 [==============================] - 0s 25ms/step
# image: 21
# 1/1 [==============================] - 0s 24ms/step
# image: 22
# 1/1 [==============================] - 0s 24ms/step
# image: 23
# 1/1 [==============================] - 0s 85ms/step
# image: 24
# 1/1 [==============================] - 0s 27ms/step
# image: 25
# 1/1 [==============================] - 0s 24ms/step
# image: 26
# 1/1 [==============================] - 0s 24ms/step
# image: 27
# 1/1 [==============================] - 0s 24ms/step
# image: 28
# 1/1 [==============================] - 0s 24ms/step
# image: 29
# 1/1 [==============================] - 0s 24ms/step
# image: 30
# 1/1 [==============================] - 0s 24ms/step
# image: 31
# 1/1 [==============================] - 0s 25ms/step
# image: 32
# 1/1 [==============================] - 0s 30ms/step
# image: 33
# 1/1 [==============================] - 0s 25ms/step
# image: 34
# 1/1 [==============================] - 0s 25ms/step
# image: 35
# 1/1 [==============================] - 0s 24ms/step
# image: 36
# 1/1 [==============================] - 0s 22ms/step
# image: 37
# 1/1 [==============================] - 0s 25ms/step
# image: 38
# 1/1 [==============================] - 0s 25ms/step
# image: 39
# 1/1 [==============================] - 0s 25ms/step
# image: 40
# 1/1 [==============================] - 0s 25ms/step
# image: 41
# 1/1 [==============================] - 0s 24ms/step
# image: 42
# 1/1 [==============================] - 0s 24ms/step
# image: 43
# 1/1 [==============================] - 0s 24ms/step
# image: 44
# 1/1 [==============================] - 0s 24ms/step
# image: 45
# 1/1 [==============================] - 0s 24ms/step
# image: 46
# 1/1 [==============================] - 0s 24ms/step
# image: 47
# 1/1 [==============================] - 0s 23ms/step
# image: 48
# 1/1 [==============================] - 0s 24ms/step
# image: 49
# 1/1 [==============================] - 0s 25ms/step
# image: 50
# 1/1 [==============================] - 0s 24ms/step
# image: 51
# 1/1 [==============================] - 0s 24ms/step
# image: 52
# 1/1 [==============================] - 0s 24ms/step
# image: 53
# 1/1 [==============================] - 0s 24ms/step
# image: 54
# 1/1 [==============================] - 0s 25ms/step
# image: 55
# 1/1 [==============================] - 0s 24ms/step
# image: 56
# 1/1 [==============================] - 0s 24ms/step
# image: 57
# 1/1 [==============================] - 0s 24ms/step
# image: 58
# 1/1 [==============================] - 0s 24ms/step
# image: 59
# 1/1 [==============================] - 0s 24ms/step
# image: 60
# 1/1 [==============================] - 0s 25ms/step
# image: 61
# 1/1 [==============================] - 0s 23ms/step
# image: 62
# 1/1 [==============================] - 0s 23ms/step
# image: 63
# 1/1 [==============================] - 0s 23ms/step
# image: 64
# 1/1 [==============================] - 0s 23ms/step
# image: 65
# 1/1 [==============================] - 0s 24ms/step
# image: 66
# 1/1 [==============================] - 0s 27ms/step
# image: 67
# 1/1 [==============================] - 0s 25ms/step
# image: 68
# 1/1 [==============================] - 0s 25ms/step
# image: 69
# 1/1 [==============================] - 0s 25ms/step
# image: 70
# 1/1 [==============================] - 0s 23ms/step
# image: 71
# 1/1 [==============================] - 0s 25ms/step
# image: 72
# 1/1 [==============================] - 0s 24ms/step
# image: 73
# 1/1 [==============================] - 0s 23ms/step
# image: 74
# 1/1 [==============================] - 0s 23ms/step
# image: 75
# 1/1 [==============================] - 0s 24ms/step
# image: 76
# 1/1 [==============================] - 0s 29ms/step
# image: 77
# 1/1 [==============================] - 0s 23ms/step
# image: 78
# 1/1 [==============================] - 0s 24ms/step
# image: 79
# 1/1 [==============================] - 0s 23ms/step
# image: 80
# 1/1 [==============================] - 0s 24ms/step
# image: 81
# 1/1 [==============================] - 0s 27ms/step
# image: 82
# 1/1 [==============================] - 0s 24ms/step
# image: 83
# 1/1 [==============================] - 0s 24ms/step
# image: 84
# 1/1 [==============================] - 0s 26ms/step
# image: 85
# 1/1 [==============================] - 0s 25ms/step
# image: 86
# 1/1 [==============================] - 0s 23ms/step
# image: 87
# 1/1 [==============================] - 0s 23ms/step
# image: 88
# 1/1 [==============================] - 0s 25ms/step
# image: 89
# 1/1 [==============================] - 0s 24ms/step
# image: 90
# 1/1 [==============================] - 0s 24ms/step
# image: 91
# 1/1 [==============================] - 0s 26ms/step
# image: 92
# 1/1 [==============================] - 0s 33ms/step
# image: 93
# 1/1 [==============================] - 0s 23ms/step
# image: 94
# 1/1 [==============================] - 0s 23ms/step
# image: 95
# 1/1 [==============================] - 0s 36ms/step
# image: 96
# 1/1 [==============================] - 0s 23ms/step
# image: 97
# 1/1 [==============================] - 0s 23ms/step
# image: 98
# 1/1 [==============================] - 0s 23ms/step
# image: 99
# 1/1 [==============================] - 0s 24ms/step
# image: 100
# 1/1 [==============================] - 0s 24ms/step
# image: 101
# 1/1 [==============================] - 0s 23ms/step
# image: 102
# 1/1 [==============================] - 0s 24ms/step
# image: 103
# 1/1 [==============================] - 0s 24ms/step
# image: 104
# 1/1 [==============================] - 0s 24ms/step
# image: 105
# 1/1 [==============================] - 0s 30ms/step
# image: 106
# 1/1 [==============================] - 0s 23ms/step
# image: 107
# 1/1 [==============================] - 0s 24ms/step
# image: 108
# 1/1 [==============================] - 0s 24ms/step
# image: 109
# 1/1 [==============================] - 0s 24ms/step
# image: 110
# 1/1 [==============================] - 0s 23ms/step
# image: 111
# 1/1 [==============================] - 0s 24ms/step
# image: 112
# 1/1 [==============================] - 0s 93ms/step
# image: 113
# 1/1 [==============================] - 0s 24ms/step
# image: 114
# 1/1 [==============================] - 0s 24ms/step
# image: 115
# 1/1 [==============================] - 0s 23ms/step
# image: 116
# 1/1 [==============================] - 0s 24ms/step
# image: 117
# 1/1 [==============================] - 0s 24ms/step
# image: 118
# 1/1 [==============================] - 0s 23ms/step
# image: 119
# 1/1 [==============================] - 0s 23ms/step
# image: 120
# 1/1 [==============================] - 0s 24ms/step
# image: 121
# 1/1 [==============================] - 0s 24ms/step
# image: 122
# 1/1 [==============================] - 0s 23ms/step
# image: 123
# 1/1 [==============================] - 0s 24ms/step
# image: 124
# 1/1 [==============================] - 0s 24ms/step
# image: 125
# 1/1 [==============================] - 0s 25ms/step
# image: 126
# image: 286
# 1/1 [==============================] - 0s 23ms/step
# image: 287
# 1/1 [==============================] - 0s 23ms/step
# image: 288
# 1/1 [==============================] - 0s 28ms/step
# image: 289
# 1/1 [==============================] - 0s 23ms/step
# image: 290
# 1/1 [==============================] - 0s 23ms/step
# image: 291
# 1/1 [==============================] - 0s 23ms/step
# image: 292
# 1/1 [==============================] - 0s 23ms/step
# image: 293
# 1/1 [==============================] - 0s 23ms/step
# image: 294
# 1/1 [==============================] - 0s 25ms/step
# image: 295
# 1/1 [==============================] - 0s 23ms/step
# image: 296
# 1/1 [==============================] - 0s 23ms/step
# image: 297
# 1/1 [==============================] - 0s 23ms/step
# image: 298
# 1/1 [==============================] - 0s 24ms/step
# image: 299
# 1/1 [==============================] - 0s 84ms/step
# Filename: /project/FoolingDetection/lib/FeatureProvider.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     44   6917.6 MiB   6917.6 MiB           1   @profile
#     45                                         def save_grids(grids_list, dataset, model, attack="correct", override=False, base_dir="/project/FoolingDetection/grids"):
#     46                                             """
#     47                                                 Save grids to disk following the path `base_dir/dataset/model/attack/technique/index` \n
#     48                                                 `grids_list`: array of grids to be stored \n
#     49                                                 `base_dir`: base directory where grids should be stored \n
#     50                                                 `dataset`: dataset the model was trained / explanined on \n
#     51                                                 `model`: type of model that was used (e.g. "cnn", "mnist", "imagenet") \n
#     52                                                 `attack`: type of attack performed; "correct" means no attack (Default) \n
#     53                                                 `override`: Determines whether previous should be overwritten or not.
#     54                                             """
#     55                                             # Define save directory
#     56   6917.6 MiB      0.0 MiB           1       base_dir = os.path.join(base_dir, dataset, model, attack)
#     57
#     58   6917.6 MiB      0.0 MiB           1       if os.path.exists(base_dir) and not override:
#     59                                                 raise Exception("The directory already exists and `override=False` was passed. Please make sure that you want to do this, this will delete any previous results.")
#     60
#     61                                             # Iterate over all grids and save them to corresponding subfolder
#     62   7994.1 MiB      0.0 MiB           7       for grids, subfolder in grids_list:
#     63   7816.1 MiB      0.0 MiB           6           subfolder_path = os.path.join(base_dir, subfolder)
#     64
#     65                                                 # Create subdirectory if it does not exist
#     66   7816.1 MiB      0.0 MiB           6           if not os.path.exists(subfolder_path):
#     67                                                     os.makedirs(subfolder_path)
#     68
#     69                                                 # Save each grid as an image
#     70   7994.1 MiB      0.0 MiB        1806           for i, grid in enumerate(grids):
#     71   7993.5 MiB      3.8 MiB        1800               plt.imshow(grid, cmap='hot', interpolation='nearest')
#     72   7993.8 MiB    896.9 MiB        1800               plt.savefig(os.path.join(subfolder_path, f"{i}.png"))
#     73   7993.8 MiB     20.2 MiB        1800               plt.clf()
#     74   7993.8 MiB      1.5 MiB        1800               plt.close()
#     75   7993.8 MiB      0.0 MiB        1800               del grid
#     76   7994.1 MiB    154.0 MiB        1800               gc.collect()
#     77   7994.1 MiB      0.0 MiB           6           del grids
#     78   7994.1 MiB      0.0 MiB           6           gc.collect()
