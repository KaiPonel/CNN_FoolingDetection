# %%
from lib.AttackProvider import run_all_attacks_on_all_models_on_all_datasets, run_all_attacks_on_all_models_on_all_datasets2

# %%
run_all_attacks_on_all_models_on_all_datasets(num_images=300)
# Out:
# Running explainers on image 10 out of 300 (3.33%)
# Running explainers on image 20 out of 300 (6.67%)
# Running explainers on image 30 out of 300 (10.00%)
# Running explainers on image 40 out of 300 (13.33%)
# Running explainers on image 50 out of 300 (16.67%)
# Running explainers on image 60 out of 300 (20.00%)
# Running explainers on image 70 out of 300 (23.33%)
# Running explainers on image 80 out of 300 (26.67%)
# Running explainers on image 90 out of 300 (30.00%)
# Running explainers on image 100 out of 300 (33.33%)
# Running explainers on image 110 out of 300 (36.67%)
# Running explainers on image 120 out of 300 (40.00%)
# Running explainers on image 130 out of 300 (43.33%)
# Running explainers on image 140 out of 300 (46.67%)
# Running explainers on image 150 out of 300 (50.00%)
# Running explainers on image 160 out of 300 (53.33%)
# Running explainers on image 170 out of 300 (56.67%)
# Running explainers on image 180 out of 300 (60.00%)
# ...

# %%
# did not want to re-run it for CNN; just need to add 'mlp' to models=[]
# I guess we can leave this as it is all_grids_3_c_umap = reduce_dimensionality_umap(all_grids_3['Cascading']['4_Linear'], 2)all_grids_3_c_umap = reduce_dimensionality_umap(all_grids_3['Cascading']['4_Linear'], 2)for now
all_grids_3_c_umap = reduce_dimensionality_umap(all_grids_3['Cascading']['4_Linear'], 2)all_grids_3_c_umap = reduce_dimensionality_umap(all_grids_3['Cascading']['4_Linear'], 2)run_all_attacks_on_all_models_on_all_datasets2(num_images=300)
# Out:
# Running explainers on image 10 out of 300 (3.33%)
# Running explainers on image 20 out of 300 (6.67%)
# Running explainers on image 30 out of 300 (10.00%)
# Running explainers on image 40 out of 300 (13.33%)
# Running explainers on image 50 out of 300 (16.67%)
# Running explainers on image 60 out of 300 (20.00%)
# Running explainers on image 70 out of 300 (23.33%)
# Running explainers on image 80 out of 300 (26.67%)
# Running explainers on image 90 out of 300 (30.00%)
# Running explainers on image 100 out of 300 (33.33%)
# Running explainers on image 110 out of 300 (36.67%)
# Running explainers on image 120 out of 300 (40.00%)
# Running explainers on image 130 out of 300 (43.33%)
# Running explainers on image 140 out of 300 (46.67%)
# Running explainers on image 150 out of 300 (50.00%)
# Running explainers on image 160 out of 300 (53.33%)
# Running explainers on image 170 out of 300 (56.67%)
# Running explainers on image 180 out of 300 (60.00%)
# ...
