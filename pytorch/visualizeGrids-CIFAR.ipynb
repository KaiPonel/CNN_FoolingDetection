# %% [markdown]
# # Visualize Grids
# This notebook is used to visualize grids for various model types, datasets and attacks

# %%
from lib.FeatureProvider import load_all_grids, load_all_grids_randparams
from lib.VisualizationProvider import visualize_grids, visualize_grids_randparams
from lib.DataProvider import load_dataset, load_CIFAR10
import matplotlib.pyplot as plt

# %% [markdown]
# # CIFAR10

# %% [markdown]
# ## CNN

# %% [markdown]
# ### Correct

# %%
correct_grids = load_all_grids(dataset="cifar10", model_type="cnn", attack="correct")
# Out:
# Loading grids from disk...
# Loading image 50 out of 300 (16.67%)
# Loading image 100 out of 300 (33.33%)
# Loading image 150 out of 300 (50.00%)
# Loading image 200 out of 300 (66.67%)
# Loading image 250 out of 300 (83.33%)
# Loading image 300 out of 300 (100.00%)
# Loading grids from disk...
# Loading image 50 out of 300 (16.67%)
# Loading image 100 out of 300 (33.33%)
# Loading image 150 out of 300 (50.00%)
# Loading image 200 out of 300 (66.67%)
# Loading image 250 out of 300 (83.33%)
# Loading image 300 out of 300 (100.00%)
# Loading grids from disk...
# Loading image 50 out of 300 (16.67%)
# Loading image 100 out of 300 (33.33%)
# Loading image 150 out of 300 (50.00%)
# Loading image 200 out of 300 (66.67%)
# Loading image 250 out of 300 (83.33%)
# Loading image 300 out of 300 (100.00%)
# Loading grids from disk...
# Loading image 50 out of 300 (16.67%)
# Loading image 100 out of 300 (33.33%)
# Loading image 150 out of 300 (50.00%)
# Loading image 200 out of 300 (66.67%)
# ...

# %%
visualize_grids(correct_grids, n=5)

# %% [markdown]
# ### RandLabels

# %%
rand_labels_grids = load_all_grids(dataset="cifar10", model_type="cnn", attack="RandLabels")
# Out:
# Loading grids from disk...
# Loading image 50 out of 300 (16.67%)
# Loading image 100 out of 300 (33.33%)
# Loading image 150 out of 300 (50.00%)
# Loading image 200 out of 300 (66.67%)
# Loading image 250 out of 300 (83.33%)
# Loading image 300 out of 300 (100.00%)
# Loading grids from disk...
# Loading image 50 out of 300 (16.67%)
# Loading image 100 out of 300 (33.33%)
# Loading image 150 out of 300 (50.00%)
# Loading image 200 out of 300 (66.67%)
# Loading image 250 out of 300 (83.33%)
# Loading image 300 out of 300 (100.00%)
# Loading grids from disk...
# Loading image 50 out of 300 (16.67%)
# Loading image 100 out of 300 (33.33%)
# Loading image 150 out of 300 (50.00%)
# Loading image 200 out of 300 (66.67%)
# Loading image 250 out of 300 (83.33%)
# Loading image 300 out of 300 (100.00%)
# Loading grids from disk...
# Loading image 50 out of 300 (16.67%)
# Loading image 100 out of 300 (33.33%)
# Loading image 150 out of 300 (50.00%)
# Loading image 200 out of 300 (66.67%)
# ...

# %%
visualize_grids(rand_labels_grids, n=5)

# %% [markdown]
# ## RandParams

# %%
rand_params_grids = load_all_grids_randparams(dataset="cifar10", model_type="cnn", attack="RandParams")
# Out:
# Loading grids from disk...
# Loading image 50 out of 300 (16.67%)
# Loading image 100 out of 300 (33.33%)
# Loading image 150 out of 300 (50.00%)
# Loading image 200 out of 300 (66.67%)
# Loading image 250 out of 300 (83.33%)
# Loading image 300 out of 300 (100.00%)
# Loading grids from disk...
# Loading image 50 out of 300 (16.67%)
# Loading image 100 out of 300 (33.33%)
# Loading image 150 out of 300 (50.00%)
# Loading image 200 out of 300 (66.67%)
# Loading image 250 out of 300 (83.33%)
# Loading image 300 out of 300 (100.00%)
# Loading grids from disk...
# Loading image 50 out of 300 (16.67%)
# Loading image 100 out of 300 (33.33%)
# Loading image 150 out of 300 (50.00%)
# Loading image 200 out of 300 (66.67%)
# Loading image 250 out of 300 (83.33%)
# Loading image 300 out of 300 (100.00%)
# Loading grids from disk...
# Loading image 50 out of 300 (16.67%)
# Loading image 100 out of 300 (33.33%)
# Loading image 150 out of 300 (50.00%)
# Loading image 200 out of 300 (66.67%)
# ...

# %% [markdown]
# ### Cascading

# %%
visualize_grids_randparams(rand_params_grids['Cascading'])
# Note: Strange indexing, this is due to using the index from enumerate(reverse(...))
# "0_{}" corresponds to the last layer, NOT the first.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_321804/2907901523.py in <module>
# ----> 1 visualize_grids_randparams(rand_params_casc_grids['Cascading'])
#       2 # Note: Strange indexing, this is due to using the index from enumerate(reverse(...))
#       3 # "0_{}" corresponds to the last layer, NOT the first.
#
# /project/FoolingDetection/pytorch/lib/VisualizationProvider.py in visualize_grids_randparams(grids, max_rows, image_size)
#      46         technique_name = technique_names[technique]
#      47
# ---> 48         n_grids = min(len(variant_grids[technique_name]) for variant_grids in grids.values()) # Number of rows possible for current technique
#      49         n_rows = min(n_grids, max_rows) # Number of rows to render, based on max_rows
#      50
#
# /project/FoolingDetection/pytorch/lib/VisualizationProvider.py in <genexpr>(.0)
# ...

# %% [markdown]
# ### Sequential

# %%
visualize_grids_randparams(rand_params_grids['Sequential'])
# Note: Strange indexing, this is due to using the index from enumerate(reverse(...))
# "0_{}" corresponds to the last layer, NOT the first.
